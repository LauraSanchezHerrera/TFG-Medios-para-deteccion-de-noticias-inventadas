# %% [markdown]
# Este jupyter notebook **"extraccion_de_datos.ipnyb"** se encarga de **construir la base de datos con el contenido de las noticias más recientes o actuales**. Accede al **RSS** de 5 periódicos: "EL MUNDO", "20 minutos", "El Confidencial", "elEconomista.es" y "La Información", para conseguir las URL's de las noticias. Cada periódico tiene una estructura de **HTML** específica, por lo que cada noticia hay que **parsearla** de forma diferente para **extraer la información que es interesante analizar**. Se extrae la URL, el título, el autor, la fecha y el contenido (texto) de la noticia.

# %%
# Librerias necesarias
import feedparser
from bs4 import BeautifulSoup
from urllib.request import urlopen
import json
import os

# %% [markdown]
# Primero, **extraigo las noticias** más recientes o actuales de los 5 periódicos:

# %%
# Se almacenan las URL's al RSS de cada periodico del que se van a extraer noticias

# Variables para almacenar las noticias
# Ruta donde estan las subcarpetas de cada periodico con sus noticias
if not os.path.exists('Noticias'):
    os.mkdir('Noticias')

# Subcarpeta para almacenar las noticias de "EL MUNDO" en el fichero "noticias.json"
if not os.path.exists('Noticias/EL MUNDO'):
    os.mkdir('Noticias/EL MUNDO')
ELMUNDO_json = 'Noticias/EL MUNDO/noticias.json'

# Subcarpeta para almacenar las noticias de "20 minutos" en el fichero "noticias.json"
if not os.path.exists('Noticias/20 minutos'):
    os.mkdir('Noticias/20 minutos')
minutos_json = 'Noticias/20 minutos/noticias.json'

# Subcarpeta para almacenar las noticias de "EL Confidencial" en el fichero "noticias.json"
if not os.path.exists('Noticias/El Confidencial'):
    os.mkdir('Noticias/El Confidencial')
ElConfidencial_json = 'Noticias/El Confidencial/noticias.json'

# Subcarpeta para almacenar las noticias de "elEconomista.es" en el fichero "noticias.json"
if not os.path.exists('Noticias/elEconomista.es'):
    os.mkdir('Noticias/elEconomista.es')
ElEconomista_json = 'Noticias/elEconomista.es/noticias.json'

# Subcarpeta para almacenar las noticias de "La Informacion" en el fichero "noticias.json"
if not os.path.exists('Noticias/La Informacion'):
    os.mkdir('Noticias/La Informacion')
LaInformacion_json = 'Noticias/La Informacion/noticias.json'

dic_urls = {} # Diccionario con el nombre del periodico y la correspondientes URL's de su RSS

# Se relaciona en el diccionario cada periodico con las URL's para acceder al RSS
dic_urls['EL MUNDO'] = ['https://e00-elmundo.uecdn.es/elmundo/rss/portada.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/espana.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/internacional.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/union_europea.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/economia.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/cultura.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/ciencia.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/madrid.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/barcelona.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/baleares.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/castillayleon.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/leon.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/valladolid.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/valencia.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/alicante.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/castellon.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/paisvasco.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/andalucia.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/andalucia_sevilla.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/andalucia_malaga.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/solidaridad.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/comunicacion.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/television.xml',
                        'https://e00-elmundo.uecdn.es/elmundo/rss/suvivienda.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/portada.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/futbol.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/baloncesto.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/ciclismo.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/golf.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/tenis.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/motor.xml',
                        'https://e00-elmundo.uecdn.es/elmundodeporte/rss/masdeporte.xml',
                        'https://e00-elmundo.uecdn.es/elmundosalud/rss/portada.xml',
                        'https://e00-elmundo.uecdn.es/elmundomotor/rss/portada.xml']

dic_urls['20 minutos'] = ['https://www.20minutos.es/rss/']

dic_urls['El Confidencial'] = ['https://rss.elconfidencial.com/espana/',
                               'https://rss.elconfidencial.com/mundo/',
                               'https://rss.elconfidencial.com/comunicacion/',
                               'https://rss.elconfidencial.com/sociedad/',
                               'https://rss.elconfidencial.com/mercados/',
                               'https://rss.elconfidencial.com/vivienda/',
                               'https://rss.elconfidencial.com/economia/',
                               'https://rss.elconfidencial.com/mercados/fondos-de-inversion/',
                               'https://rss.elconfidencial.com/empresas/',
                               'https://rss.elconfidencial.com/mercados/finanzas-personales/',
                               'https://rss.elconfidencial.com/tags/temas/apps-9337/',
                               'https://rss.elconfidencial.com/tags/temas/internet-9342/',
                               'https://rss.elconfidencial.com/tags/economia/emprendedores-4800/',
                               'https://rss.elconfidencial.com/tags/otros/moviles-8601/',
                               'https://rss.elconfidencial.com/deportes/futbol/',
                               'https://rss.elconfidencial.com/deportes/tenis/',
                               'https://rss.elconfidencial.com/deportes/baloncesto/',
                               'https://rss.elconfidencial.com/deportes/ciclismo/',
                               'https://rss.elconfidencial.com/deportes/golf/',
                               'https://rss.elconfidencial.com/deportes/motociclismo/',
                               'https://rss.elconfidencial.com/deportes/otros-deportes/',
                               'https://rss.elconfidencial.com/tags/otros/alimentacion-5601/',
                               'https://rss.elconfidencial.com/tags/otros/salud-6110/',
                               'https://rss.elconfidencial.com/tags/temas/bienestar-9331/',
                               'https://rss.elconfidencial.com/tags/economia/trabajo-5284/',
                               'https://rss.vanitatis.elconfidencial.com/noticias/',
                               'https://rss.vanitatis.elconfidencial.com/casas-reales/',
                               'https://rss.alimente.elconfidencial.com/nutricion',
                               'https://rss.alimente.elconfidencial.com/bienestar/']

dic_urls['elEconomista.es'] = ['https://www.eleconomista.es/rss/rss-emprendedores.php',
                               'https://www.eleconomista.es/rss/rss-ecoley.php',
                               'https://www.eleconomista.es/rss/rss-gestion.php',
                               'https://www.eleconomista.es/rss/rss-fondos.php',
                               'https://www.eleconomista.es/rss/rss-category.php?category=tecnologia',
                               'https://www.eleconomista.es/rss/rss-economia.php',
                               'https://www.eleconomista.es/rss/rss-mercados.php',
                               'https://www.eleconomista.es/rss/rss-empresas.php',
                               'https://www.eleconomista.es/rss/rss-seleccion-ee.php',
                               'https://www.eleconomista.es/rss/rss-evasion.php',
                               'https://www.eleconomista.es/rss/rss-espania.php',
                               'https://www.eleconomista.es/rss/rss-global.php',
                               'https://www.eleconomista.es/rss/rss-deportes.php',
                               'https://www.eleconomista.es/rss/rss-cultura.php',
                               'https://www.eleconomista.es/rss/rss-medio-ambiente.php']

dic_urls['La Informacion'] = ['https://www.lainformacion.com/rss/']

# %%
# Se accede a los RSS de los periodicos de la coleccion
num_noticias = 0 # Contador de noticias
dic_noticias = {} # Diccionario con el periodico y las noticias recopiladas, extraidas del RSS

# Por cada periodico se accede a las URL's de su RSS
for periodico in dic_urls.items():
    dic_noticias[periodico[0]] = [] # La clave es el periodico
    
    # Se accede a cada URL del RSS
    for url_rss in periodico[1]:
        # Al ser un fichero XML hay que parsearlo para poder leerlo
        rss = feedparser.parse(url_rss)

        # Se recorren todas las noticias que aparecen en el RSS
        for post in rss.entries:
            num_noticias += 1 # Se aumenta el numero de noticias recopiladas
            dic_noticias[periodico[0]].append(post.link) # Se guarda la URL de la noticia

print("En total, se han recopilado " + str(num_noticias) + " noticias.")
# Out:
# En total, se han recopilado 1835 noticias.

# %%
#   1834. https://www.lainformacion.com/management/entrevistas-trabajo-como-responder-preguntas-subestimadas/2863631/
#   1835. https://www.lainformacion.com/management/ofertas-empleo-dazn-editores-video-ciberseguridad/2863621/

# %%
# Se muestra el numero de noticias recopiladas en cada periodico
print("Noticias recopiladas en cada periodico:")
for noticias in dic_noticias.items():
    num_noticias = 0
    for html in noticias[1]:
        num_noticias += 1
    
    print("  - " + noticias[0] + ": " + str(num_noticias))
# Out:
# Noticias recopiladas en cada periodico:
#   - EL MUNDO: 1290
#   - 20 minutos: 98
#   - El Confidencial: 353
#   - elEconomista.es: 45
#   - La Informacion: 49

# %% [markdown]
# Es posible, haber **perdido las urls** de las noticias recopiladas, ya sea por reiniciar el ordenar, etc. Está la posibilidad de **recuperarlas**, ya que se han almacenado en disco, **leyendo el fichero "urls.json"** donde están almacenadas las urls de las noticias de todos los periódicos:

# %%
import json
import os

with open(urls_json) as file:
    dic_noticias = json.load(file)

# %% [markdown]
# Una vez se ha recopilado todas las noticias del RSS de los 5 periódicos, se pasa a **parsear su HTML y construir la base datos**:

# %% [markdown]
# Parseando el periódico **"EL MUNDO"**:

# %%
# Parseando el html de las noticias del periodico EL MUNDO

num_noticias = 0 # Numero de noticias totales
num_noticias_accesibles = 0 # Guarda el numero de noticias que se han podido leer
num_noticias_descartadas = 0 # Guarda el numero de noticias que finalmente se han descartado, ya que estan ocultas
dic_json = {} # Diccionario para almacenar los datos de las noticias

# Se empieza a parsear y almacenar los datos accediendo a la URL de cada noticia
for noticia in dic_noticias['EL MUNDO']:
    soup = BeautifulSoup(urlopen(noticia).read(), "lxml") # Se lee el HTML de la noticia
    num_noticias += 1 # Se aumenta el numero de noticias leidas

    # Es posible que no se pueda acceder al contenido de las noticias de tipo premium ni bajo registro, se descartan
    if len(soup.find_all('div', class_="ue-c-article__premium-tag ue-c-article__premium-tag--signwall")) != 0: 
        print(str(num_noticias) + ": BAJO REGISTRO, no esta accesible")
        num_noticias_descartadas += 1 # Se aumenta el numero de noticias descartadas
    elif len(soup.find_all('div', class_="ue-c-article__premium-tag")) != 0:
        print(str(num_noticias) + ": PREMIUM, no esta accesible")
        num_noticias_descartadas += 1 # Se aumenta el numero de noticias descartadas
    # Si se trata de una portada tambien se descarta
    elif "Portada" in soup.title.text:
        print(str(num_noticias) + ": Se trata de una portada")
        num_noticias_descartadas += 1 # Se aumenta el numero de noticias descartadas
    
    # Si no es una portada, limitada bajo registro o premium, se pasa a extraer los datos
    else:
        print(str(num_noticias) + ": Es accesible")
        num_noticias_accesibles += 1 # Se aumenta el numero de noticias accesibles
        dic_json[num_noticias] = {} # Los datos de cada noticia se almacena con la clave del numero de noticia
        
        # Se almacena la URL de la noticia
        dic_json[num_noticias]['url'] = noticia
        
        # Se accede al titulo de la noticia y se almacena
        dic_json[num_noticias]['titulo'] = soup.title.text
        
        # Se accede al autor y se almacena
        for autor in soup.find_all('div', class_="ue-c-article__byline-name"):
            autor = autor.get_text()
            if '\n' in autor:
                autor = autor.split('\n')[1]
            dic_json[num_noticias]['autor'] = autor
            
        # Se accede a la fecha y se almacena
        if soup.find_all('time') != []:
            dic_json[num_noticias]['fecha'] = soup.find_all('time')[0]['datetime']
        else:
            dic_json[num_noticias]['fecha'] = "Muy antigua" # Es posible que no se indique la fecha
        
        # Se comprueba si hay comentarios, para que no los tome como contenido de la noticia
        list_comentarios = [] # Lista de los comentarios que tenga la noticia
        for comentario in soup.find_all('div', class_='texto-comentario'):
            list_comentarios.append(comentario.get_text().split('\n')[1])
        for comentario in soup.find_all('div', id="comentarios_lectores_listado"):
            list_comentarios = comentario.get_text().split('\n')

        # Se comrueba si hay enlace al tiempo, para que no lo tome como contenido de la noticia
        list_tiempo = [] # Lista de los enlaces al tiempo que tenga la noticia
        for elem in soup.find_all('a', href="/tiempo/index.html"):
            list_tiempo.append(elem.get_text())

        # Se comprueba si se da la opcion de registrarse o iniciar sesion, para que no lo tome como contenido de la noticia
        list_sesion = [] # Lista de la opcion de registrarse o iniciar sesion que tenga la noticia
        for label in soup.find_all('form', action="/social/login/"):
            list_sesion = label.get_text().split('\n')

        # Se comprueba si da la opcion de enviar un mensaje privado, para que no lo tome como contenido de la noticia
        list_mensaje = [] # Lista de la opcion de enviar un mensaje privado que tenga la noticia
        for label in soup.find_all('div', class_="contenido_mensaje_privado"):
            list_mensaje.append(label.get_text().split('\n')[2])

        # Se comprueba si contiene titulos de imagenes o videos, para que no lo tome como contenido de la noticia
        list_titulos = [] # Lista de los titulos de imagenes o videos que tenga la noticia
        for titl in soup.find_all('div', id="modulo_multimedia"):
            list_titulos = titl.get_text().split("\n")
        for titl in soup.find_all('div', class_="foto"):
            list_titulos.append(titl.get_text())

        # Se accede al contenido de la noticia y se almacena
        contenido = ""
        # Se lee primero la cabecera de la noticia
        for p in soup.find_all('p', class_="ue-c-article--first-letter-highlighted"):
            # Se comprueba si se trata de un comentario, del enlace al tiempo, del registro o de la opcion de enviar un mensaje, o un titulo
            c = p.get_text()
            if len(c.split('\n')) > 3:
                c = c.split('\n')[2]

            if c not in list_comentarios and c not in list_tiempo and c not in list_sesion and c not in list_mensaje and c not in list_titulos:
                contenido += c
                
        
        # Se lee el resto de la noticia
        for p in soup.find_all('p', class_=''):
            # Se comrpueba si se trata de un comentario, del enlace al tiempo, del registro, de la opcion de enviar un mensaje, o un titulo
            c = p.get_text()
            if len(c.split('\n')) > 3:
                c = c.split('\n')[2]

            if c not in list_comentarios and c not in list_tiempo and c not in list_sesion and c not in list_mensaje and c not in list_titulos:
                contenido += c
        
        # En el caso de que sea una entrevista
        for dl in soup.find_all('dl', class_="ue-c-article__interview"):
            contenido += dl.get_text()
            
        dic_json[num_noticias]['contenido'] = contenido
        
print("EL MUNDO -> noticias parseadas " + str(num_noticias_accesibles) + " noticias descartadas " + str(num_noticias_descartadas) + " = " + str(num_noticias_accesibles + num_noticias_descartadas))
            
# Se almacena en disco el dic_json generado en el fichero noticias.json dentro de la subcarpeta "EL MUNDO"
with open(ELMUNDO_json, 'w') as fp:
    json.dump(dic_json, fp, indent=4)
# Out:
# 1: Es accesible
# 2: PREMIUM, no esta accesible
# 3: PREMIUM, no esta accesible
# 4: PREMIUM, no esta accesible
# 5: PREMIUM, no esta accesible
# 6: PREMIUM, no esta accesible
# 7: Es accesible
# 8: PREMIUM, no esta accesible
# 9: PREMIUM, no esta accesible
# 10: Es accesible
# 11: PREMIUM, no esta accesible
# 12: PREMIUM, no esta accesible
# 13: Es accesible
# 14: PREMIUM, no esta accesible
# 15: Es accesible
# 16: Es accesible
# 17: Es accesible
# 18: PREMIUM, no esta accesible
# 19: Es accesible
# 20: Es accesible
# 21: Es accesible
# 22: Es accesible
# 23: PREMIUM, no esta accesible
# 24: Es accesible
# 25: Es accesible
# 26: Es accesible
# 27: Es accesible
# 28: Es accesible
# 29: PREMIUM, no esta accesible
# 30: Es accesible
# 31: Es accesible
# 32: Es accesible
# 33: Es accesible
# 34: Es accesible
# 35: PREMIUM, no esta accesible
# 36: Es accesible
# 37: PREMIUM, no esta accesible
# 38: Es accesible
# 39: Es accesible
# 40: Es accesible
# 41: Es accesible
# 42: Es accesible
# 43: PREMIUM, no esta accesible
# 44: PREMIUM, no esta accesible
# 45: PREMIUM, no esta accesible
# 46: Es accesible
# 47: Es accesible
# 48: Es accesible
# 49: Es accesible
# 50: Es accesible
# 51: Es accesible
# 52: Es accesible
# 53: Es accesible
# 54: PREMIUM, no esta accesible
# 55: PREMIUM, no esta accesible
# 56: PREMIUM, no esta accesible
# 57: Es accesible
# 58: Es accesible
# 59: Es accesible
# 60: Es accesible
# 61: Es accesible
# 62: Es accesible
# 63: Es accesible
# 64: Es accesible
# 65: Es accesible
# 66: Es accesible
# 67: PREMIUM, no esta accesible
# 68: PREMIUM, no esta accesible
# 69: Es accesible
# 70: Es accesible
# 71: Es accesible
# 72: Es accesible
# 73: Es accesible
# 74: Es accesible
# 75: PREMIUM, no esta accesible
# 76: Es accesible
# 77: Es accesible
# 78: Es accesible
# 79: Es accesible
# 80: PREMIUM, no esta accesible
# 81: Es accesible
# 82: Es accesible
# 83: PREMIUM, no esta accesible
# 84: Es accesible
# 85: Es accesible
# 86: Es accesible
# 87: Es accesible
# 88: Es accesible
# 89: Es accesible
# 90: Es accesible
# 91: PREMIUM, no esta accesible
# 92: Es accesible
# 93: Es accesible
# 94: PREMIUM, no esta accesible
# 95: PREMIUM, no esta accesible
# 96: PREMIUM, no esta accesible
# 97: PREMIUM, no esta accesible
# 98: PREMIUM, no esta accesible
# 99: Es accesible
# 100: PREMIUM, no esta accesible
# 101: PREMIUM, no esta accesible
# 102: PREMIUM, no esta accesible
# 103: Es accesible
# 104: Es accesible
# 105: Es accesible
# 106: Es accesible
# 107: PREMIUM, no esta accesible
# 108: Es accesible
# 109: Es accesible
# 110: Es accesible
# 111: Es accesible
# 112: Es accesible
# 113: Es accesible
# 114: PREMIUM, no esta accesible
# 115: PREMIUM, no esta accesible
# 116: Es accesible
# 117: PREMIUM, no esta accesible
# 118: PREMIUM, no esta accesible
# 119: PREMIUM, no esta accesible
# 120: Es accesible
# 121: PREMIUM, no esta accesible
# 122: Es accesible
# 123: Es accesible
# 124: PREMIUM, no esta accesible
# 125: Es accesible
# 126: PREMIUM, no esta accesible
# 127: PREMIUM, no esta accesible
# 128: PREMIUM, no esta accesible
# 129: Es accesible
# 130: Es accesible
# 131: Es accesible
# 132: Es accesible
# 133: PREMIUM, no esta accesible
# 134: Es accesible
# 135: PREMIUM, no esta accesible
# 136: Es accesible
# 137: PREMIUM, no esta accesible
# 138: Es accesible
# 139: PREMIUM, no esta accesible
# 140: Es accesible
# 141: Es accesible
# 142: PREMIUM, no esta accesible
# 143: PREMIUM, no esta accesible
# 144: PREMIUM, no esta accesible
# 145: Es accesible
# 146: Es accesible
# 147: Es accesible
# 148: Es accesible
# 149: Es accesible
# 150: Es accesible
# 151: Es accesible
# 152: Es accesible
# 153: Es accesible
# 154: PREMIUM, no esta accesible
# 155: Es accesible
# 156: Es accesible
# 157: PREMIUM, no esta accesible
# 158: Es accesible
# 159: PREMIUM, no esta accesible
# 160: Es accesible
# 161: Es accesible
# 162: Es accesible
# 163: Es accesible
# 164: Es accesible
# 165: PREMIUM, no esta accesible
# 166: Es accesible
# 167: Es accesible
# 168: Es accesible
# 169: PREMIUM, no esta accesible
# 170: Es accesible
# 171: Es accesible
# 172: Es accesible
# 173: Es accesible
# 174: Es accesible
# 175: Es accesible
# 176: Es accesible
# 177: Es accesible
# 178: Es accesible
# 179: Es accesible
# 180: Es accesible
# 181: Es accesible
# 182: Es accesible
# 183: Es accesible
# 184: Es accesible
# 185: Es accesible
# 186: Es accesible
# 187: Es accesible
# 188: Es accesible
# 189: Es accesible
# 190: Es accesible
# 191: Es accesible
# 192: Es accesible
# 193: PREMIUM, no esta accesible
# 194: PREMIUM, no esta accesible
# 195: Es accesible
# 196: Es accesible
# 197: Es accesible
# 198: Es accesible
# 199: Es accesible
# 200: Es accesible
# 201: Es accesible
# 202: Es accesible
# 203: Es accesible
# 204: Es accesible
# 205: PREMIUM, no esta accesible
# 206: PREMIUM, no esta accesible
# 207: Es accesible
# 208: PREMIUM, no esta accesible
# 209: Es accesible
# 210: PREMIUM, no esta accesible
# 211: PREMIUM, no esta accesible
# 212: PREMIUM, no esta accesible
# 213: Es accesible
# 214: PREMIUM, no esta accesible
# 215: Es accesible
# 216: Es accesible
# 217: Es accesible
# 218: Es accesible
# 219: Es accesible
# 220: Es accesible
# 221: Es accesible
# 222: Es accesible
# 223: Es accesible
# 224: Es accesible
# 225: PREMIUM, no esta accesible
# 226: PREMIUM, no esta accesible
# 227: Es accesible
# 228: Es accesible
# 229: Es accesible
# 230: Es accesible
# 231: Es accesible
# 232: Es accesible
# 233: Es accesible
# 234: Es accesible
# 235: Es accesible
# 236: Es accesible
# 237: Es accesible
# 238: Es accesible
# 239: Es accesible
# 240: PREMIUM, no esta accesible
# 241: Es accesible
# 242: Es accesible
# 243: Es accesible
# 244: PREMIUM, no esta accesible
# 245: Es accesible
# 246: Es accesible
# 247: Es accesible
# 248: Es accesible
# 249: Es accesible
# 250: Es accesible
# 251: Es accesible
# 252: PREMIUM, no esta accesible
# 253: Es accesible
# 254: Es accesible
# 255: Es accesible
# 256: Es accesible
# 257: Es accesible
# 258: Es accesible
# 259: Es accesible
# 260: Es accesible
# 261: Es accesible
# 262: Es accesible
# 263: Es accesible
# 264: Es accesible
# 265: Es accesible
# 266: Es accesible
# 267: Es accesible
# 268: Es accesible
# 269: Es accesible
# 270: Es accesible
# 271: PREMIUM, no esta accesible
# 272: Es accesible
# 273: Es accesible
# 274: Es accesible
# 275: Es accesible
# 276: Es accesible
# 277: Es accesible
# 278: Es accesible
# 279: Es accesible
# 280: Es accesible
# 281: Es accesible
# 282: Es accesible
# 283: Es accesible
# 284: Es accesible
# 285: Es accesible
# 286: Es accesible
# 287: PREMIUM, no esta accesible
# 288: Es accesible
# 289: Es accesible
# 290: Es accesible
# 291: Es accesible
# 292: Es accesible
# 293: Es accesible
# 294: Es accesible
# 295: Es accesible
# 296: Es accesible
# 297: Es accesible
# 298: PREMIUM, no esta accesible
# 299: PREMIUM, no esta accesible
# 300: PREMIUM, no esta accesible
# 301: Es accesible
# 302: Es accesible
# 303: Es accesible
# 304: Es accesible
# 305: Es accesible
# 306: Es accesible
# 307: Es accesible
# 308: Es accesible
# 309: Es accesible
# 310: Es accesible
# 311: PREMIUM, no esta accesible
# 312: Es accesible
# 313: Es accesible
# 314: Es accesible
# 315: Es accesible
# 316: Es accesible
# 317: Es accesible
# 318: Es accesible
# 319: Es accesible
# 320: Es accesible
# 321: Es accesible
# 322: Es accesible
# 323: Es accesible
# 324: Es accesible
# 325: Es accesible
# 326: Es accesible
# 327: Es accesible
# 328: Es accesible
# 329: Es accesible
# 330: Es accesible
# 331: Es accesible
# 332: Es accesible
# 333: Es accesible
# 334: Es accesible
# 335: Es accesible
# 336: Es accesible
# 337: Es accesible
# 338: Es accesible
# 339: Es accesible
# 340: Es accesible
# 341: Es accesible
# 342: Es accesible
# 343: Es accesible
# 344: Es accesible
# 345: Es accesible
# 346: Es accesible
# 347: Es accesible
# 348: Es accesible
# 349: Es accesible
# 350: Es accesible
# 351: Es accesible
# 352: Es accesible
# 353: Es accesible
# 354: Es accesible
# 355: Es accesible
# 356: Es accesible
# 357: Es accesible
# 358: Es accesible
# 359: Es accesible
# 360: Es accesible
# 361: Es accesible
# 362: Es accesible
# 363: Es accesible
# 364: Es accesible
# 365: Es accesible
# 366: Es accesible
# 367: Es accesible
# 368: Es accesible
# 369: Es accesible
# 370: Es accesible
# 371: Es accesible
# 372: Es accesible
# 373: Es accesible
# 374: Es accesible
# 375: Es accesible
# 376: Es accesible
# 377: Es accesible
# 378: Es accesible
# 379: Es accesible
# 380: Es accesible
# 381: Es accesible
# 382: Es accesible
# 383: Es accesible
# 384: Es accesible
# 385: Es accesible
# 386: Es accesible
# 387: Es accesible
# 388: Es accesible
# 389: Es accesible
# 390: Es accesible
# 391: Es accesible
# 392: PREMIUM, no esta accesible
# 393: Es accesible
# 394: Es accesible
# 395: Es accesible
# 396: Es accesible
# 397: PREMIUM, no esta accesible
# 398: Es accesible
# 399: Es accesible
# 400: Es accesible
# 401: Es accesible
# 402: Es accesible
# 403: Es accesible
# 404: Es accesible
# 405: Es accesible
# 406: Es accesible
# 407: Es accesible
# 408: Es accesible
# 409: Es accesible
# 410: Es accesible
# 411: Es accesible
# 412: Es accesible
# 413: Es accesible
# 414: Es accesible
# 415: Es accesible
# 416: Es accesible
# 417: Es accesible
# 418: Es accesible
# 419: Es accesible
# 420: Es accesible
# 421: Es accesible
# 422: Es accesible
# 423: Es accesible
# 424: Es accesible
# 425: Es accesible
# 426: Es accesible
# 427: Es accesible
# 428: Es accesible
# 429: Es accesible
# 430: Es accesible
# 431: Es accesible
# 432: Es accesible
# 433: Es accesible
# 434: Es accesible
# 435: Es accesible
# 436: Es accesible
# 437: Es accesible
# 438: Es accesible
# 439: Es accesible
# 440: Es accesible
# 441: Es accesible
# 442: Es accesible
# 443: Es accesible
# 444: Es accesible
# 445: Es accesible
# 446: Es accesible
# 447: Es accesible
# 448: Es accesible
# 449: Es accesible
# 450: Es accesible
# 451: Es accesible
# 452: Es accesible
# 453: Es accesible
# 454: Es accesible
# 455: Es accesible
# 456: PREMIUM, no esta accesible
# 457: Es accesible
# 458: Es accesible
# 459: Es accesible
# 460: Es accesible
# 461: Es accesible
# 462: Es accesible
# 463: Es accesible
# 464: Es accesible
# 465: Es accesible
# 466: Es accesible
# 467: Es accesible
# 468: Es accesible
# 469: Es accesible
# 470: Es accesible
# 471: Es accesible
# 472: Es accesible
# 473: Es accesible
# 474: Es accesible
# 475: Es accesible
# 476: Es accesible
# 477: Es accesible
# 478: Es accesible
# 479: Es accesible
# 480: Es accesible
# 481: Es accesible
# 482: Es accesible
# 483: Es accesible
# 484: Es accesible
# 485: Es accesible
# 486: Es accesible
# 487: Es accesible
# 488: Es accesible
# 489: Es accesible
# 490: Es accesible
# 491: Es accesible
# 492: Es accesible
# 493: Es accesible
# 494: Es accesible
# 495: Es accesible
# 496: Es accesible
# 497: Es accesible
# 498: Es accesible
# 499: Es accesible
# 500: Es accesible
# 501: Es accesible
# 502: Es accesible
# 503: Es accesible
# 504: Es accesible
# 505: Es accesible
# 506: Es accesible
# 507: Es accesible
# 508: Es accesible
# 509: Es accesible
# 510: Es accesible
# 511: Es accesible
# 512: Es accesible
# 513: Es accesible
# 514: Es accesible
# 515: Es accesible
# 516: Es accesible
# 517: Es accesible
# 518: Es accesible
# 519: Es accesible
# 520: Es accesible
# 521: Es accesible
# 522: Es accesible
# 523: Es accesible
# 524: Es accesible
# 525: Es accesible
# 526: Es accesible
# 527: Es accesible
# 528: Es accesible
# 529: Es accesible
# 530: Es accesible
# 531: Es accesible
# 532: Es accesible
# 533: Es accesible
# 534: Es accesible
# 535: Es accesible
# 536: Es accesible
# 537: Es accesible
# 538: Es accesible
# 539: Es accesible
# 540: Es accesible
# 541: Es accesible
# 542: Es accesible
# 543: Es accesible
# 544: Es accesible
# 545: Es accesible
# 546: Es accesible
# 547: Es accesible
# 548: Es accesible
# 549: Es accesible
# 550: Es accesible
# 551: Es accesible
# 552: Es accesible
# 553: Es accesible
# 554: Es accesible
# 555: Es accesible
# 556: Es accesible
# 557: Es accesible
# 558: Es accesible
# 559: Es accesible
# 560: Es accesible
# 561: Es accesible
# 562: Es accesible
# 563: Es accesible
# 564: Es accesible
# 565: Es accesible
# 566: Es accesible
# 567: Es accesible
# 568: Es accesible
# 569: Es accesible
# 570: Es accesible
# 571: Es accesible
# 572: Es accesible
# 573: Es accesible
# 574: Es accesible
# 575: Es accesible
# 576: Es accesible
# 577: Es accesible
# 578: Es accesible
# 579: Es accesible
# 580: Es accesible
# 581: Es accesible
# 582: Es accesible
# 583: Es accesible
# 584: Es accesible
# 585: Es accesible
# 586: Es accesible
# 587: Es accesible
# 588: Es accesible
# 589: Es accesible
# 590: Es accesible
# 591: Es accesible
# 592: Es accesible
# 593: Es accesible
# 594: Es accesible
# 595: Es accesible
# 596: Es accesible
# 597: Es accesible
# 598: Es accesible
# 599: Es accesible
# 600: Es accesible
# 601: Es accesible
# 602: Es accesible
# 603: Es accesible
# 604: Es accesible
# 605: Es accesible
# 606: Es accesible
# 607: Es accesible
# 608: Es accesible
# 609: Es accesible
# 610: Es accesible
# 611: Es accesible
# 612: Es accesible
# 613: Es accesible
# 614: Es accesible
# 615: Es accesible
# 616: Es accesible
# 617: Es accesible
# 618: Es accesible
# 619: Es accesible
# 620: Es accesible
# 621: Es accesible
# 622: Es accesible
# 623: Es accesible
# 624: Es accesible
# 625: Es accesible
# 626: Es accesible
# 627: Es accesible
# 628: Es accesible
# 629: Es accesible
# 630: Es accesible
# 631: Es accesible
# 632: Es accesible
# 633: Es accesible
# 634: Es accesible
# 635: Es accesible
# 636: Es accesible
# 637: Es accesible
# 638: Es accesible
# 639: Es accesible
# 640: PREMIUM, no esta accesible
# 641: Es accesible
# 642: Es accesible
# 643: Es accesible
# 644: Es accesible
# 645: Es accesible
# 646: Es accesible
# 647: Es accesible
# 648: Es accesible
# 649: Es accesible
# 650: Es accesible
# 651: PREMIUM, no esta accesible
# 652: Es accesible
# 653: Es accesible
# 654: Es accesible
# 655: Es accesible
# 656: Es accesible
# 657: Es accesible
# 658: Es accesible
# 659: Es accesible
# 660: Es accesible
# 661: Es accesible
# 662: Es accesible
# 663: Es accesible
# 664: Es accesible
# 665: Es accesible
# 666: Es accesible
# 667: Es accesible
# 668: Es accesible
# 669: Es accesible
# 670: Es accesible
# 671: Es accesible
# 672: Es accesible
# 673: Es accesible
# 674: Es accesible
# 675: Es accesible
# 676: Es accesible
# 677: Es accesible
# 678: Es accesible
# 679: Es accesible
# 680: Es accesible
# 681: Es accesible
# 682: Es accesible
# 683: Es accesible
# 684: Es accesible
# 685: Es accesible
# 686: Es accesible
# 687: Es accesible
# 688: Es accesible
# 689: Es accesible
# 690: Es accesible
# 691: Es accesible
# 692: PREMIUM, no esta accesible
# 693: Es accesible
# 694: Es accesible
# 695: Es accesible
# 696: Es accesible
# 697: Es accesible
# 698: Es accesible
# 699: Es accesible
# 700: Es accesible
# 701: Es accesible
# 702: Es accesible
# 703: Es accesible
# 704: Es accesible
# 705: Es accesible
# 706: Es accesible
# 707: Es accesible
# 708: Es accesible
# 709: PREMIUM, no esta accesible
# 710: PREMIUM, no esta accesible
# 711: Es accesible
# 712: Es accesible
# 713: Es accesible
# 714: Es accesible
# 715: PREMIUM, no esta accesible
# 716: Es accesible
# 717: Es accesible
# 718: Es accesible
# 719: Es accesible
# 720: Es accesible
# 721: PREMIUM, no esta accesible
# 722: Es accesible
# 723: Es accesible
# 724: PREMIUM, no esta accesible
# 725: Es accesible
# 726: Es accesible
# 727: Es accesible
# 728: Es accesible
# 729: PREMIUM, no esta accesible
# 730: PREMIUM, no esta accesible
# 731: Es accesible
# 732: PREMIUM, no esta accesible
# 733: Es accesible
# 734: Es accesible
# 735: Es accesible
# 736: Es accesible
# 737: PREMIUM, no esta accesible
# 738: Es accesible
# 739: Es accesible
# 740: Es accesible
# 741: Es accesible
# 742: Es accesible
# 743: Es accesible
# 744: Es accesible
# 745: Es accesible
# 746: PREMIUM, no esta accesible
# 747: Es accesible
# 748: PREMIUM, no esta accesible
# 749: Es accesible
# 750: Es accesible
# 751: Es accesible
# 752: PREMIUM, no esta accesible
# 753: PREMIUM, no esta accesible
# 754: Es accesible
# 755: Es accesible
# 756: Es accesible
# 757: Es accesible
# 758: Es accesible
# 759: Es accesible
# 760: Es accesible
# 761: Es accesible
# 762: PREMIUM, no esta accesible
# 763: Es accesible
# 764: Es accesible
# 765: Es accesible
# 766: Es accesible
# 767: Es accesible
# 768: Es accesible
# 769: Es accesible
# 770: Es accesible
# 771: PREMIUM, no esta accesible
# 772: Es accesible
# 773: PREMIUM, no esta accesible
# 774: PREMIUM, no esta accesible
# 775: Es accesible
# 776: Es accesible
# 777: Es accesible
# 778: Es accesible
# 779: Es accesible
# 780: Es accesible
# 781: Es accesible
# 782: Es accesible
# 783: Es accesible
# 784: Es accesible
# 785: PREMIUM, no esta accesible
# 786: Es accesible
# 787: Es accesible
# 788: PREMIUM, no esta accesible
# 789: Es accesible
# 790: PREMIUM, no esta accesible
# 791: Es accesible
# 792: Es accesible
# 793: Es accesible
# 794: Es accesible
# 795: Es accesible
# 796: Es accesible
# 797: Es accesible
# 798: Es accesible
# 799: Es accesible
# 800: Es accesible
# 801: Es accesible
# 802: Es accesible
# 803: Es accesible
# 804: Es accesible
# 805: Es accesible
# 806: Es accesible
# 807: Es accesible
# 808: Es accesible
# 809: Es accesible
# 810: Es accesible
# 811: Es accesible
# 812: Es accesible
# 813: Es accesible
# 814: Es accesible
# 815: Es accesible
# 816: Es accesible
# 817: Es accesible
# 818: PREMIUM, no esta accesible
# 819: Es accesible
# 820: Es accesible
# 821: PREMIUM, no esta accesible
# 822: Es accesible
# 823: Es accesible
# 824: Es accesible
# 825: Se trata de una portada
# 826: Es accesible
# 827: Es accesible
# 828: Es accesible
# 829: Es accesible
# 830: Es accesible
# 831: Es accesible
# 832: PREMIUM, no esta accesible
# 833: Es accesible
# 834: Es accesible
# 835: Es accesible
# 836: Es accesible
# 837: PREMIUM, no esta accesible
# 838: Es accesible
# 839: Es accesible
# 840: Es accesible
# 841: Es accesible
# 842: PREMIUM, no esta accesible
# 843: Es accesible
# 844: Es accesible
# 845: Es accesible
# 846: PREMIUM, no esta accesible
# 847: Es accesible
# 848: Es accesible
# 849: PREMIUM, no esta accesible
# 850: PREMIUM, no esta accesible
# 851: Es accesible
# 852: Es accesible
# 853: Es accesible
# 854: Se trata de una portada
# 855: Es accesible
# 856: Es accesible
# 857: Es accesible
# 858: Es accesible
# 859: Es accesible
# 860: Es accesible
# 861: Es accesible
# 862: Es accesible
# 863: Se trata de una portada
# 864: Es accesible
# 865: Es accesible
# 866: Es accesible
# 867: Es accesible
# 868: Es accesible
# 869: Es accesible
# 870: Es accesible
# 871: Se trata de una portada
# 872: Es accesible
# 873: Es accesible
# 874: Es accesible
# 875: Es accesible
# 876: Es accesible
# 877: Es accesible
# 878: Es accesible
# 879: Es accesible
# 880: Es accesible
# 881: Es accesible
# 882: Se trata de una portada
# 883: Es accesible
# 884: Es accesible
# 885: Es accesible
# 886: Es accesible
# 887: Es accesible
# 888: Es accesible
# 889: Es accesible
# 890: Es accesible
# 891: Se trata de una portada
# 892: Es accesible
# 893: Es accesible
# 894: Es accesible
# 895: Se trata de una portada
# 896: Es accesible
# 897: Se trata de una portada
# 898: Es accesible
# 899: Es accesible
# 900: Se trata de una portada
# 901: Es accesible
# 902: Es accesible
# 903: Es accesible
# 904: PREMIUM, no esta accesible
# 905: PREMIUM, no esta accesible
# 906: Es accesible
# 907: PREMIUM, no esta accesible
# 908: Es accesible
# 909: Es accesible
# 910: Es accesible
# 911: PREMIUM, no esta accesible
# 912: Es accesible
# 913: Es accesible
# 914: PREMIUM, no esta accesible
# 915: Es accesible
# 916: Es accesible
# 917: PREMIUM, no esta accesible
# 918: Es accesible
# 919: Es accesible
# 920: PREMIUM, no esta accesible
# 921: Es accesible
# 922: Es accesible
# 923: Es accesible
# 924: Es accesible
# 925: Es accesible
# 926: Es accesible
# 927: Es accesible
# 928: Es accesible
# 929: Es accesible
# 930: Es accesible
# 931: Es accesible
# 932: Es accesible
# 933: Es accesible
# 934: PREMIUM, no esta accesible
# 935: Es accesible
# 936: Es accesible
# 937: Es accesible
# 938: Es accesible
# 939: Es accesible
# 940: Es accesible
# 941: Es accesible
# 942: Es accesible
# 943: Es accesible
# 944: Es accesible
# 945: Es accesible
# 946: Es accesible
# 947: Es accesible
# 948: PREMIUM, no esta accesible
# 949: Es accesible
# 950: Es accesible
# 951: Es accesible
# 952: Es accesible
# 953: Es accesible
# 954: Es accesible
# 955: Es accesible
# 956: Es accesible
# 957: Es accesible
# 958: Es accesible
# 959: Es accesible
# 960: Es accesible
# 961: Es accesible
# 962: Es accesible
# 963: Es accesible
# 964: Es accesible
# 965: Es accesible
# 966: Es accesible
# 967: PREMIUM, no esta accesible
# 968: Es accesible
# 969: Es accesible
# 970: Es accesible
# 971: Es accesible
# 972: Es accesible
# 973: Es accesible
# 974: Es accesible
# 975: Es accesible
# 976: Es accesible
# 977: Es accesible
# 978: Es accesible
# 979: Es accesible
# 980: Es accesible
# 981: Es accesible
# 982: Es accesible
# 983: Es accesible
# 984: PREMIUM, no esta accesible
# 985: Es accesible
# 986: PREMIUM, no esta accesible
# 987: Es accesible
# 988: Es accesible
# 989: Es accesible
# 990: Es accesible
# 991: Es accesible
# 992: Es accesible
# 993: Es accesible
# 994: Es accesible
# 995: Es accesible
# 996: Es accesible
# 997: Es accesible
# 998: Es accesible
# 999: Es accesible
# 1000: Es accesible
# 1001: PREMIUM, no esta accesible
# 1002: Es accesible
# 1003: Es accesible
# 1004: Es accesible
# 1005: Es accesible
# 1006: Es accesible
# 1007: Es accesible
# 1008: PREMIUM, no esta accesible
# 1009: Es accesible
# 1010: Es accesible
# 1011: Es accesible
# 1012: PREMIUM, no esta accesible
# 1013: Es accesible
# 1014: PREMIUM, no esta accesible
# 1015: Es accesible
# 1016: PREMIUM, no esta accesible
# 1017: Es accesible
# 1018: Es accesible
# 1019: Es accesible
# 1020: Es accesible
# 1021: Es accesible
# 1022: Es accesible
# 1023: Es accesible
# 1024: Es accesible
# 1025: Es accesible
# 1026: Es accesible
# 1027: Es accesible
# 1028: Es accesible
# 1029: Es accesible
# 1030: PREMIUM, no esta accesible
# 1031: Es accesible
# 1032: PREMIUM, no esta accesible
# 1033: Es accesible
# 1034: Es accesible
# 1035: Es accesible
# 1036: Es accesible
# 1037: Es accesible
# 1038: Es accesible
# 1039: Es accesible
# 1040: Es accesible
# 1041: Es accesible
# 1042: Es accesible
# 1043: Es accesible
# 1044: Es accesible
# 1045: Es accesible
# 1046: Es accesible
# 1047: Es accesible
# 1048: PREMIUM, no esta accesible
# 1049: Es accesible
# 1050: Es accesible
# 1051: Es accesible
# 1052: Es accesible
# 1053: Es accesible
# 1054: Es accesible
# 1055: Es accesible
# 1056: Es accesible
# 1057: Es accesible
# 1058: Es accesible
# 1059: Es accesible
# 1060: Es accesible
# 1061: Es accesible
# 1062: Es accesible
# 1063: Es accesible
# 1064: Es accesible
# 1065: Es accesible
# 1066: Es accesible
# 1067: Es accesible
# 1068: PREMIUM, no esta accesible
# 1069: Es accesible
# 1070: Es accesible
# 1071: Es accesible
# 1072: Es accesible
# 1073: PREMIUM, no esta accesible
# 1074: Es accesible
# 1075: Es accesible
# 1076: Es accesible
# 1077: PREMIUM, no esta accesible
# 1078: Es accesible
# 1079: Es accesible
# 1080: Es accesible
# 1081: PREMIUM, no esta accesible
# 1082: Es accesible
# 1083: Es accesible
# 1084: PREMIUM, no esta accesible
# 1085: Es accesible
# 1086: Es accesible
# 1087: Es accesible
# 1088: Es accesible
# 1089: Es accesible
# 1090: Es accesible
# 1091: Es accesible
# 1092: PREMIUM, no esta accesible
# 1093: Es accesible
# 1094: Es accesible
# 1095: Es accesible
# 1096: Es accesible
# 1097: Es accesible
# 1098: Es accesible
# 1099: Es accesible
# 1100: Es accesible
# 1101: Es accesible
# 1102: Es accesible
# 1103: Es accesible
# 1104: Es accesible
# 1105: Es accesible
# 1106: Es accesible
# 1107: Es accesible
# 1108: Es accesible
# 1109: Es accesible
# 1110: Es accesible
# 1111: Es accesible
# 1112: Es accesible
# 1113: Es accesible
# 1114: Es accesible
# 1115: Es accesible
# 1116: Es accesible
# 1117: Es accesible
# 1118: Es accesible
# 1119: Es accesible
# 1120: Es accesible
# 1121: Es accesible
# 1122: Es accesible
# 1123: Es accesible
# 1124: Es accesible
# 1125: Es accesible
# 1126: Es accesible
# 1127: PREMIUM, no esta accesible
# 1128: Es accesible
# 1129: Es accesible
# 1130: Es accesible
# 1131: Es accesible
# 1132: Es accesible
# 1133: Es accesible
# 1134: Es accesible
# 1135: Es accesible
# 1136: Es accesible
# 1137: Es accesible
# 1138: Es accesible
# 1139: Es accesible
# 1140: Es accesible
# 1141: Es accesible
# 1142: Es accesible
# 1143: PREMIUM, no esta accesible
# 1144: PREMIUM, no esta accesible
# 1145: Es accesible
# 1146: Es accesible
# 1147: Es accesible
# 1148: Es accesible
# 1149: Es accesible
# 1150: Es accesible
# 1151: Es accesible
# 1152: Es accesible
# 1153: Es accesible
# 1154: Es accesible
# 1155: Es accesible
# 1156: Es accesible
# 1157: Es accesible
# 1158: Es accesible
# 1159: Es accesible
# 1160: Es accesible
# 1161: Es accesible
# 1162: Es accesible
# 1163: Es accesible
# 1164: Es accesible
# 1165: Es accesible
# 1166: Es accesible
# 1167: Es accesible
# 1168: Es accesible
# 1169: Es accesible
# 1170: Es accesible
# 1171: Es accesible
# 1172: Es accesible
# 1173: Es accesible
# 1174: Es accesible
# 1175: Es accesible
# 1176: Es accesible
# 1177: Es accesible
# 1178: Es accesible
# 1179: PREMIUM, no esta accesible
# 1180: Es accesible
# 1181: Es accesible
# 1182: PREMIUM, no esta accesible
# 1183: Es accesible
# 1184: Es accesible
# 1185: Es accesible
# 1186: Es accesible
# 1187: Es accesible
# 1188: Es accesible
# 1189: Es accesible
# 1190: Es accesible
# 1191: Es accesible
# 1192: Es accesible
# 1193: Es accesible
# 1194: Es accesible
# 1195: Es accesible
# 1196: Es accesible
# 1197: Es accesible
# 1198: Es accesible
# 1199: Es accesible
# 1200: Es accesible
# 1201: Es accesible
# 1202: Es accesible
# 1203: Es accesible
# 1204: Es accesible
# 1205: Es accesible
# 1206: Es accesible
# 1207: Es accesible
# 1208: Es accesible
# 1209: Es accesible
# 1210: Es accesible
# 1211: Es accesible
# 1212: Es accesible
# 1213: Es accesible
# 1214: Es accesible
# 1215: Es accesible
# 1216: Es accesible
# 1217: Es accesible
# 1218: Es accesible
# 1219: Es accesible
# 1220: Es accesible
# 1221: Es accesible
# 1222: Es accesible
# 1223: Es accesible
# 1224: Es accesible
# 1225: Es accesible
# 1226: Es accesible
# 1227: Es accesible
# 1228: Es accesible
# 1229: Es accesible
# 1230: Es accesible
# 1231: Es accesible
# 1232: Es accesible
# 1233: Es accesible
# 1234: Es accesible
# 1235: Es accesible
# 1236: Es accesible
# 1237: Es accesible
# 1238: Es accesible
# 1239: Es accesible
# 1240: Es accesible
# 1241: Es accesible
# 1242: Es accesible
# 1243: Es accesible
# 1244: Es accesible
# 1245: Es accesible
# 1246: Es accesible
# 1247: Es accesible
# 1248: Es accesible
# 1249: Es accesible
# 1250: Es accesible
# 1251: Es accesible
# 1252: Es accesible
# 1253: Es accesible
# 1254: Es accesible
# 1255: Es accesible
# 1256: Es accesible
# 1257: Es accesible
# 1258: Es accesible
# 1259: Es accesible
# 1260: Es accesible
# 1261: Es accesible
# 1262: Es accesible
# 1263: Es accesible
# 1264: Es accesible
# 1265: Es accesible
# 1266: Es accesible
# 1267: Es accesible
# 1268: Es accesible
# 1269: Es accesible
# 1270: Es accesible
# 1271: Es accesible
# 1272: Es accesible
# 1273: Es accesible
# 1274: Es accesible
# 1275: Es accesible
# 1276: Es accesible
# 1277: Es accesible
# 1278: Es accesible
# 1279: Es accesible
# 1280: Es accesible
# 1281: PREMIUM, no esta accesible
# 1282: Es accesible
# 1283: Es accesible
# 1284: Es accesible
# 1285: Es accesible
# 1286: Es accesible
# 1287: Es accesible
# 1288: Es accesible
# 1289: Es accesible
# 1290: Es accesible
# EL MUNDO -> noticias parseadas 1137 noticias descartadas 153 = 1290

# %% [markdown]
# Parseando el periódico **"20 minutos"**:

# %%
# Parseando el html de las noticias del periodico 20 minutos

num_noticias = 0 # Numero de noticias totales
num_noticias_accesibles = 0 # Guarda el numero de noticias que se han podido leer
num_noticias_descartadas = 0 # Guarda el numero de noticias que finalmente se han descartado, ya que estan ocultas
dic_json = {} # Diccionario para almacenar los datos de las noticias

# Se empieza a parsear y almacenar los datos accediendo a la URL de cada noticia
for noticia in dic_noticias['20 minutos']:
    soup = BeautifulSoup(urlopen(noticia).read(), "lxml") # Se lee el HTML de la noticia
    num_noticias += 1 # Se aumenta el numero de noticias leida
    
    # Se comprueba si la noticia se trata de un video, si es asi se descarta
    if "Vídeo:" not in (soup.title.text).lstrip() and "Fotos:" not in (soup.title.text).lstrip():
        print(str(num_noticias) + ": Es accesible")
        num_noticias_accesibles += 1 # Se aumenta el numero de noticias accesibles
        dic_json[num_noticias] = {} # Los datos de cada noticia se almacena con la clave del numero de noticia

        # Se almacena la url de la noticia
        dic_json[num_noticias]['url'] = noticia

        # Se accede al titulo de la noticia y se almacena
        dic_json[num_noticias]['titulo'] = (soup.title.text).lstrip()

        # Se accede al autor y se almacena
        for autor in soup.find_all('strong'):
            autor = autor.get_text()
            if '\n' in autor:
                autor = autor.split('\n')[1]
            dic_json[num_noticias]['autor'] = autor
            break

        # Se accede a la fecha y se almacena
        if soup.find_all('meta', property="article:published_time") != []:
            dic_json[num_noticias]['fecha'] = soup.find_all('meta', property="article:published_time")[0]['content']
        else:
            dic_json[num_noticias]['fecha'] = "Muy antigua" # Es posible que no se indique la fecha

        # Se accede al contenido de la noticia y se almacena
        # Se saca el article articleBody
        cont = 0
        for p in soup.find_all("script",type="application/ld+json"):
            if cont == 1:
                html_articleBody = p
            cont += 1

        # Se convierte el objeto a algo tratable como un json
        for letra in html_articleBody:
            json_article = json.dumps(letra)

        #Una vez se tiene el json ahora es el momento de sacar el texto de la noticia
        contenido = ""
        texto = True
        for c in json_article.split("articleBody")[1].split("\"")[2]:
            if c == "<":
                texto = False
            if texto:
                contenido += c
            if c == ">":
                texto = True

        dic_json[num_noticias]['contenido'] = contenido
        
    else:
        print(str(num_noticias) + ": Se trata de una foto o video")
        num_noticias_descartadas += 1 # Se aumenta el numero de noticias descartadas
        
print("20 minutos -> noticias parseadas " + str(num_noticias_accesibles) + " noticias descartadas " + str(num_noticias_descartadas) + " = " + str(num_noticias_accesibles + num_noticias_descartadas))
            
# Se almacena en disco el dic_json generado en el fichero noticias.json dentro de la subcarpeta "20 minutos"
with open(minutos_json, 'w') as fp:
    json.dump(dic_json, fp, indent=4)
# Out:
# 1: Es accesible
# 2: Es accesible
# 3: Es accesible
# 4: Es accesible
# 5: Es accesible
# 6: Es accesible
# 7: Es accesible
# 8: Es accesible
# 9: Es accesible
# 10: Es accesible
# 11: Es accesible
# 12: Es accesible
# 13: Es accesible
# 14: Es accesible
# 15: Es accesible
# 16: Es accesible
# 17: Es accesible
# 18: Es accesible
# 19: Es accesible
# 20: Es accesible
# 21: Es accesible
# 22: Es accesible
# 23: Es accesible
# 24: Es accesible
# 25: Es accesible
# 26: Es accesible
# 27: Es accesible
# 28: Es accesible
# 29: Es accesible
# 30: Es accesible
# 31: Es accesible
# 32: Es accesible
# 33: Es accesible
# 34: Es accesible
# 35: Es accesible
# 36: Es accesible
# 37: Es accesible
# 38: Es accesible
# 39: Es accesible
# 40: Se trata de una foto o video
# 41: Se trata de una foto o video
# 42: Se trata de una foto o video
# 43: Se trata de una foto o video
# 44: Se trata de una foto o video
# 45: Es accesible
# 46: Es accesible
# 47: Es accesible
# 48: Es accesible
# 49: Es accesible
# 50: Se trata de una foto o video
# 51: Es accesible
# 52: Es accesible
# 53: Es accesible
# 54: Se trata de una foto o video
# 55: Es accesible
# 56: Es accesible
# 57: Es accesible
# 58: Es accesible
# 59: Es accesible
# 60: Es accesible
# 61: Es accesible
# 62: Es accesible
# 63: Es accesible
# 64: Es accesible
# 65: Es accesible
# 66: Se trata de una foto o video
# 67: Es accesible
# 68: Se trata de una foto o video
# 69: Es accesible
# 70: Es accesible
# 71: Es accesible
# 72: Es accesible
# 73: Es accesible
# 74: Es accesible
# 75: Es accesible
# 76: Es accesible
# 77: Es accesible
# 78: Es accesible
# 79: Es accesible
# 80: Es accesible
# 81: Es accesible
# 82: Es accesible
# 83: Es accesible
# 84: Es accesible
# 85: Es accesible
# 86: Es accesible
# 87: Es accesible
# 88: Es accesible
# 89: Es accesible
# 90: Es accesible
# 91: Es accesible
# 92: Es accesible
# 93: Es accesible
# 94: Es accesible
# 95: Es accesible
# 96: Es accesible
# 97: Es accesible
# 98: Es accesible
# 20 minutos -> noticias parseadas 89 noticias descartadas 9 = 98

# %% [markdown]
# Parseando el periódico **"El Confidencial"**:

# %%
# Parseando el html de las noticias del periodico El Confidencial

num_noticias = 0 # Numero de noticias totales
num_noticias_accesibles = 0 # Guarda el numero de noticias que se han podido leer
num_noticias_descartadas = 0 # Guarda el numero de noticias que finalmente se han descartado, ya que estan ocultas
dic_json = {} # Diccionario para almacenar los datos de las noticias

# Se empieza a parsear y almacenar los datos accediendo a la URL de cada noticia
for noticia in dic_noticias['El Confidencial']:
    try:
        soup = BeautifulSoup(urlopen(noticia).read(), "lxml") # Se lee el HTML de la noticia
        num_noticias += 1 # Se aumenta el numero de noticias leida   
        num_noticias_accesibles += 1 # Se aumenta el numero de noticias accesibles
        print(str(num_noticias) + ": Es accesible")
        dic_json[num_noticias] = {} # Los datos de cada noticia se almacena con la clave del numero de noticia

        #Se almacena la url de la noticia
        dic_json[num_noticias]['url'] = noticia

        # Se almacena el titulo de la noticia y se almacena
        dic_json[num_noticias]['titulo'] = (soup.title.text).lstrip()
        
        #Se accede al autor de la noticia y se almacena
        autor = ""
        for nombre in soup.find_all('a', class_="authorSignature__link"):
            autor += nombre.get_text()
        dic_json[num_noticias]['autor'] = autor
        
        # Se accede a la fecha y se almacena
        if soup.find_all('meta', property="og:article:published_time") != []:
            dic_json[num_noticias]['fecha'] = soup.find_all('meta', property="og:article:published_time")[0]['content']
        else:
            dic_json[num_noticias]['fecha'] = "Muy antigua" # Es posible que no se indique la fecha
            
        # Se accede al contenido de la noticia y se almacena
        contenido = ""
        for text in soup.find_all('div', class_="newsType__content"):
            texto = text.get_text()
            contenido += texto.split(" — ")[0]
        dic_json[num_noticias]['contenido'] = contenido
        
    except:
        # A veces devuelve un HTTP Error que no se puede controlar, es aleatorio
        num_noticias_descartadas += 1
        print(str(num_noticias) + ": HTTP Error")
   
        
print("El Confidencial -> noticias parseadas " + str(num_noticias_accesibles) + " noticias descartadas " + str(num_noticias_descartadas) + " = " + str(num_noticias_accesibles + num_noticias_descartadas))
            
# Se almacena en disco el dic_json generado en el fichero noticias.json dentro de la subcarpeta "El Confidencial"
with open(ElConfidencial_json, 'w') as fp:
    json.dump(dic_json, fp, indent=4)
# Out:
# 1: Es accesible
# 2: Es accesible
# 3: Es accesible
# 4: Es accesible
# 5: Es accesible
# 6: Es accesible
# 7: Es accesible
# 8: Es accesible
# 9: Es accesible
# 10: Es accesible
# 11: Es accesible
# 12: Es accesible
# 13: Es accesible
# 14: Es accesible
# 15: Es accesible
# 16: Es accesible
# 17: Es accesible
# 18: Es accesible
# 19: Es accesible
# 20: Es accesible
# 21: Es accesible
# 22: Es accesible
# 23: Es accesible
# 24: Es accesible
# 25: Es accesible
# 26: Es accesible
# 27: Es accesible
# 28: Es accesible
# 29: Es accesible
# 30: Es accesible
# 31: Es accesible
# 32: Es accesible
# 33: Es accesible
# 34: Es accesible
# 35: Es accesible
# 36: Es accesible
# 37: Es accesible
# 38: Es accesible
# 39: Es accesible
# 40: Es accesible
# 41: Es accesible
# 42: Es accesible
# 43: Es accesible
# 44: Es accesible
# 45: Es accesible
# 46: Es accesible
# 46: HTTP Error
# 47: Es accesible
# 48: Es accesible
# 49: Es accesible
# 50: Es accesible
# 51: Es accesible
# 52: Es accesible
# 53: Es accesible
# 54: Es accesible
# 55: Es accesible
# 56: Es accesible
# 57: Es accesible
# 58: Es accesible
# 59: Es accesible
# 60: Es accesible
# 61: Es accesible
# 62: Es accesible
# 62: HTTP Error
# 63: Es accesible
# 64: Es accesible
# 65: Es accesible
# 66: Es accesible
# 67: Es accesible
# 68: Es accesible
# 69: Es accesible
# 70: Es accesible
# 71: Es accesible
# 72: Es accesible
# 73: Es accesible
# 74: Es accesible
# 75: Es accesible
# 75: HTTP Error
# 75: HTTP Error
# 76: Es accesible
# 77: Es accesible
# 78: Es accesible
# 79: Es accesible
# 80: Es accesible
# 81: Es accesible
# 82: Es accesible
# 83: Es accesible
# 84: Es accesible
# 85: Es accesible
# 86: Es accesible
# 87: Es accesible
# 88: Es accesible
# 89: Es accesible
# 90: Es accesible
# 91: Es accesible
# 92: Es accesible
# 93: Es accesible
# 94: Es accesible
# 95: Es accesible
# 95: HTTP Error
# 95: HTTP Error
# 96: Es accesible
# 96: HTTP Error
# 97: Es accesible
# 97: HTTP Error
# 98: Es accesible
# 98: HTTP Error
# 98: HTTP Error
# 99: Es accesible
# 100: Es accesible
# 101: Es accesible
# 101: HTTP Error
# 102: Es accesible
# 103: Es accesible
# 104: Es accesible
# 105: Es accesible
# 106: Es accesible
# 107: Es accesible
# 108: Es accesible
# 109: Es accesible
# 110: Es accesible
# 110: HTTP Error
# 110: HTTP Error
# 110: HTTP Error
# 111: Es accesible
# 112: Es accesible
# 112: HTTP Error
# 112: HTTP Error
# 112: HTTP Error
# 113: Es accesible
# 114: Es accesible
# 115: Es accesible
# 116: Es accesible
# 117: Es accesible
# 118: Es accesible
# 119: Es accesible
# 120: Es accesible
# 121: Es accesible
# 122: Es accesible
# 122: HTTP Error
# 123: Es accesible
# 124: Es accesible
# 124: HTTP Error
# 124: HTTP Error
# 125: Es accesible
# 125: HTTP Error
# 125: HTTP Error
# 125: HTTP Error
# 126: Es accesible
# 127: Es accesible
# 128: Es accesible
# 129: Es accesible
# 130: Es accesible
# 131: Es accesible
# 132: Es accesible
# 133: Es accesible
# 134: Es accesible
# 135: Es accesible
# 136: Es accesible
# 137: Es accesible
# 138: Es accesible
# 139: Es accesible
# 140: Es accesible
# 141: Es accesible
# 142: Es accesible
# 143: Es accesible
# 144: Es accesible
# 145: Es accesible
# 146: Es accesible
# 147: Es accesible
# 148: Es accesible
# 149: Es accesible
# 149: HTTP Error
# 150: Es accesible
# 151: Es accesible
# 152: Es accesible
# 152: HTTP Error
# 153: Es accesible
# 154: Es accesible
# 155: Es accesible
# 155: HTTP Error
# 156: Es accesible
# 156: HTTP Error
# 156: HTTP Error
# 156: HTTP Error
# 157: Es accesible
# 157: HTTP Error
# 157: HTTP Error
# 157: HTTP Error
# 157: HTTP Error
# 157: HTTP Error
# 157: HTTP Error
# 158: Es accesible
# 159: Es accesible
# 159: HTTP Error
# 160: Es accesible
# 161: Es accesible
# 162: Es accesible
# 163: Es accesible
# 163: HTTP Error
# 163: HTTP Error
# 163: HTTP Error
# 163: HTTP Error
# 163: HTTP Error
# 163: HTTP Error
# 163: HTTP Error
# 164: Es accesible
# 165: Es accesible
# 165: HTTP Error
# 165: HTTP Error
# 165: HTTP Error
# 165: HTTP Error
# 165: HTTP Error
# 165: HTTP Error
# 165: HTTP Error
# 166: Es accesible
# 166: HTTP Error
# 166: HTTP Error
# 166: HTTP Error
# 166: HTTP Error
# 166: HTTP Error
# 166: HTTP Error
# 166: HTTP Error
# 167: Es accesible
# 168: Es accesible
# 169: Es accesible
# 170: Es accesible
# 170: HTTP Error
# 170: HTTP Error
# 170: HTTP Error
# 170: HTTP Error
# 171: Es accesible
# 171: HTTP Error
# 171: HTTP Error
# 171: HTTP Error
# 172: Es accesible
# 172: HTTP Error
# 173: Es accesible
# 174: Es accesible
# 175: Es accesible
# 175: HTTP Error
# 176: Es accesible
# 177: Es accesible
# 177: HTTP Error
# 177: HTTP Error
# 178: Es accesible
# 178: HTTP Error
# 179: Es accesible
# 179: HTTP Error
# 180: Es accesible
# 180: HTTP Error
# 180: HTTP Error
# 181: Es accesible
# 182: Es accesible
# 182: HTTP Error
# 182: HTTP Error
# 182: HTTP Error
# 183: Es accesible
# 184: Es accesible
# 184: HTTP Error
# 184: HTTP Error
# 184: HTTP Error
# 185: Es accesible
# 185: HTTP Error
# 186: Es accesible
# 187: Es accesible
# 188: Es accesible
# 188: HTTP Error
# 188: HTTP Error
# 188: HTTP Error
# 189: Es accesible
# 189: HTTP Error
# 189: HTTP Error
# 189: HTTP Error
# 190: Es accesible
# 191: Es accesible
# 191: HTTP Error
# 192: Es accesible
# 193: Es accesible
# 194: Es accesible
# 194: HTTP Error
# 195: Es accesible
# 195: HTTP Error
# 195: HTTP Error
# 196: Es accesible
# 196: HTTP Error
# 197: Es accesible
# 198: Es accesible
# 199: Es accesible
# 200: Es accesible
# 200: HTTP Error
# 201: Es accesible
# 201: HTTP Error
# 202: Es accesible
# 203: Es accesible
# 203: HTTP Error
# 203: HTTP Error
# 203: HTTP Error
# 203: HTTP Error
# 203: HTTP Error
# 204: Es accesible
# 204: HTTP Error
# 204: HTTP Error
# 205: Es accesible
# 205: HTTP Error
# 205: HTTP Error
# 206: Es accesible
# 207: Es accesible
# 208: Es accesible
# 209: Es accesible
# 210: Es accesible
# 211: Es accesible
# 212: Es accesible
# 213: Es accesible
# 214: Es accesible
# 215: Es accesible
# 216: Es accesible
# 217: Es accesible
# 218: Es accesible
# 219: Es accesible
# 220: Es accesible
# 221: Es accesible
# 222: Es accesible
# 223: Es accesible
# 224: Es accesible
# 225: Es accesible
# 226: Es accesible
# 227: Es accesible
# 228: Es accesible
# 229: Es accesible
# 230: Es accesible
# 231: Es accesible
# 232: Es accesible
# 233: Es accesible
# 234: Es accesible
# 235: Es accesible
# 236: Es accesible
# 237: Es accesible
# 238: Es accesible
# 239: Es accesible
# 240: Es accesible
# 241: Es accesible
# 242: Es accesible
# 243: Es accesible
# 244: Es accesible
# 245: Es accesible
# 246: Es accesible
# 247: Es accesible
# 247: HTTP Error
# 248: Es accesible
# 249: Es accesible
# 250: Es accesible
# 251: Es accesible
# El Confidencial -> noticias parseadas 251 noticias descartadas 102 = 353

# %% [markdown]
# Parseando el periódico **"elEconomista.es"**:

# %%
# Parseando el html de las noticias del periodico elEconomista.es

num_noticias = 0 # Numero de noticias totales
num_noticias_accesibles = 0 # Guarda el numero de noticias que se han podido leer
num_noticias_descartadas = 0 # Guarda el numero de noticias que finalmente se han descartado, ya que estan ocultas
dic_json = {} # Diccionario para almacenar los datos de las noticias

# Se empieza a parsear y almacenar los datos accediendo a la URL de cada noticia
for noticia in dic_noticias['elEconomista.es']:
    soup = BeautifulSoup(urlopen(noticia).read(), "lxml") # Se lee el HTML de la noticia
    num_noticias += 1 # Se aumenta el numero de noticias leida   
    num_noticias_accesibles += 1 # Se aumenta el numero de noticias accesibles
    print(str(num_noticias) + ": Es accesible")
    dic_json[num_noticias] = {} # Los datos de cada noticia se almacena con la clave del numero de noticia

    # Se almacena la url de la noticia
    dic_json[num_noticias]['url'] = noticia

    # Se accede al titulo de la noticia y se almacena
    dic_json[num_noticias]['titulo'] = (soup.title.text).lstrip()
    
    # Se accede al autor de la noticia y se almacena
    autor = ""
    for nombre in soup.find_all('div', class_="authors_Name d-inline-flex"):
        autor += nombre.get_text()
    dic_json[num_noticias]['autor'] = autor
    
    # Se accede a la fecha y se almacena
    if soup.find_all(attrs={"name": "date"}) != []:
        dic_json[num_noticias]['fecha'] = soup.find_all(attrs={"name": "date"})[0]['content']
    else:
        dic_json[num_noticias]['fecha'] = "Muy antigua" # Es posible que no se indique la fecha

    # Se accede al contenido de la noticia y se almacena
    contenido = ""
    for nombre in soup.find_all('p'):
        contenido += nombre.get_text()
    dic_json[num_noticias]['contenido'] = contenido
        
print("elEconomista.es -> noticias parseadas " + str(num_noticias_accesibles) + " noticias descartadas " + str(num_noticias_descartadas) + " = " + str(num_noticias_accesibles + num_noticias_descartadas))
            
# Se almacena en disco el dic_json generado en el fichero noticias.json dentro de la subcarpeta "elEconomista.es"
with open(ElEconomista_json, 'w') as fp:
    json.dump(dic_json, fp, indent=4)
# Out:
# 1: Es accesible
# 2: Es accesible
# 3: Es accesible
# 4: Es accesible
# 5: Es accesible
# 6: Es accesible
# 7: Es accesible
# 8: Es accesible
# 9: Es accesible
# 10: Es accesible
# 11: Es accesible
# 12: Es accesible
# 13: Es accesible
# 14: Es accesible
# 15: Es accesible
# 16: Es accesible
# 17: Es accesible
# 18: Es accesible
# 19: Es accesible
# 20: Es accesible
# 21: Es accesible
# 22: Es accesible
# 23: Es accesible
# 24: Es accesible
# 25: Es accesible
# 26: Es accesible
# 27: Es accesible
# 28: Es accesible
# 29: Es accesible
# 30: Es accesible
# 31: Es accesible
# 32: Es accesible
# 33: Es accesible
# 34: Es accesible
# 35: Es accesible
# 36: Es accesible
# 37: Es accesible
# 38: Es accesible
# 39: Es accesible
# 40: Es accesible
# 41: Es accesible
# 42: Es accesible
# 43: Es accesible
# 44: Es accesible
# 45: Es accesible
# elEconomista.es -> noticias parseadas 45 noticias descartadas 0 = 45

# %% [markdown]
# Parseando el periódico **"La Información"**:

# %%
# Parseando el html de las noticias del periodico La Informacion

num_noticias = 0 # Numero de noticias totales
num_noticias_accesibles = 0 # Guarda el numero de noticias que se han podido leer
num_noticias_descartadas = 0 # Guarda el numero de noticias que finalmente se han descartado, ya que estan ocultas
dic_json = {} # Diccionario para almacenar los datos de las noticias

# Se empieza a parsear y almacenar los datos accediendo a la URL de cada noticia
for noticia in dic_noticias['La Informacion']:
    soup = BeautifulSoup(urlopen(noticia).read(), "lxml") # Se lee el HTML de la noticia
    num_noticias += 1 # Se aumenta el numero de noticias leida  
    num_noticias_accesibles += 1
    print(str(num_noticias) + ": Es accesible")
    dic_json[num_noticias] = {} # Los datos de cada noticia se almacena con la clave del numero de noticia

    # Se almacena la url de la noticia
    dic_json[num_noticias]['url'] = noticia

    # Se accede al titulo de la noticia y se almacena
    dic_json[num_noticias]['titulo'] = (soup.title.text).lstrip()
    
    # Se accede al autor de la noticia y se almacena
    autor = ""
    for nombre in soup.find_all('span', class_="article-author"):
        autor += nombre.get_text()
    dic_json[num_noticias]['autor'] = autor
    
    # Se accede a la fecha y se almacena
    if soup.find_all('meta', property="article:published_time") != []:
            dic_json[num_noticias]['fecha'] = soup.find_all('meta', property="article:published_time")[0]['content']
    else:
        dic_json[num_noticias]['fecha'] = "Muy antigua" # Es posible que no se indique la fecha

    # Se accede al contenido de la noticia y se almacena
    contenido = ""
    for nombre in soup.find_all('p'):
        if "La Informaci\u00f3n. Calle Canarias" not in nombre.get_text() and "S\u00edguenos tambi\u00e9n en:" not in nombre.get_text():
            contenido += nombre.get_text()
    dic_json[num_noticias]['contenido'] = contenido
        
print("La Informacion -> noticias parseadas " + str(num_noticias_accesibles) + " noticias descartadas " + str(num_noticias_descartadas) + " = " + str(num_noticias_accesibles + num_noticias_descartadas))
            
# Se almacena en disco el dic_json generado en el fichero noticias.json dentro de la subcarpeta "La Informacion"
with open(LaInformacion_json, 'w') as fp:
    json.dump(dic_json, fp, indent=4)
# Out:
# 1: Es accesible
# 2: Es accesible
# 3: Es accesible
# 4: Es accesible
# 5: Es accesible
# 6: Es accesible
# 7: Es accesible
# 8: Es accesible
# 9: Es accesible
# 10: Es accesible
# 11: Es accesible
# 12: Es accesible
# 13: Es accesible
# 14: Es accesible
# 15: Es accesible
# 16: Es accesible
# 17: Es accesible
# 18: Es accesible
# 19: Es accesible
# 20: Es accesible
# 21: Es accesible
# 22: Es accesible
# 23: Es accesible
# 24: Es accesible
# 25: Es accesible
# 26: Es accesible
# 27: Es accesible
# 28: Es accesible
# 29: Es accesible
# 30: Es accesible
# 31: Es accesible
# 32: Es accesible
# 33: Es accesible
# 34: Es accesible
# 35: Es accesible
# 36: Es accesible
# 37: Es accesible
# 38: Es accesible
# 39: Es accesible
# 40: Es accesible
# 41: Es accesible
# 42: Es accesible
# 43: Es accesible
# 44: Es accesible
# 45: Es accesible
# 46: Es accesible
# 47: Es accesible
# 48: Es accesible
# 49: Es accesible
# La Informacion -> noticias parseadas 49 noticias descartadas 0 = 49
